# %% [markdown]
# #  The Spark Foundation - GRIP Program

# %% [markdown]
# # Task-1  Object Detection
# This perform to identifies the classes of the object in an image.

# %% [markdown]
# # Author : Rammya Dharshini K
#  Email Id: rammyadharshinik@gmail.com
#
#  Linkedin Id: https://www.linkedin.com/in/rammya-dharshini-k-95b74318b/
#
#  Github Profile:

# %% [markdown]
# # Required Librry is imported

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %% [markdown]
# # Loading the image

# %%
im = cv2.imread('fruits.jpg')

# %% [markdown]
# # Detect classes in object

# %%
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im,bbox,label,conf)

# %% [markdown]
# # Output image

# %%
plt.imshow(output_image)
plt.show()

# %% [markdown]
# # Thank You
